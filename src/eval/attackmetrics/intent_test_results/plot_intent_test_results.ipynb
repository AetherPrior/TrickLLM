# %%
data = {
    "TURBO": [
        {
            "total_success_fraction": 0.5495327102803739
        },
        {
            "lang": 0.25882352941176473,
            "hate": 0.013525698827772768,
            "summary": 0.9044481054365733,
            "code": 0.8914473684210527
        },
        {
            "goal hijack": 0.3105542900531511,
            "prompt leakage": 0.6666666666666666,
            "denial of service": 0.6881644223954642
        },
        {
            "few-shot hacking": 0.2988668555240793,
            "indirect task deflection": 0.9876847290640394,
            "instruction based hacking": 0.6074380165289256,
            "syntactical change": 0.5016393442622951,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.39644970414201186,
            "cognitive hacking": 0.9951219512195122
        },
        [
            {
                "lang": 0.5717011128775834,
                "hate": 0.6446274949430947,
                "summary": 0.37975867135669444,
                "code": 0.3836237553342816
            },
            {
                "goal hijack": 0.556321697551766,
                "prompt leakage": 0.4504504504504504,
                "denial of service": 0.4440592257743215
            },
            {
                "few-shot hacking": 0.5597963402495981,
                "indirect task deflection": 0.3550126481160964,
                "instruction based hacking": 0.4680589680589681,
                "syntactical change": 0.49951262738147983,
                "insisting": 0.6486486486486487,
                "text-completion vs instruction tradeoff": 0.5307852230929154,
                "cognitive hacking": 0.3528015820698747
            }
        ],
        {
            "goal hijack": 1317,
            "prompt leakage": 1017,
            "denial of service": 1411
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "codex": [
        {
            "total_success_fraction": 0.5169559412550067
        },
        {
            "lang": 0.07254901960784314,
            "hate": 0.0009017132551848512,
            "summary": 0.8871499176276771,
            "code": 0.9002192982456141
        },
        {
            "goal hijack": 0.3363705391040243,
            "prompt leakage": 0.6096361848574238,
            "denial of service": 0.6187101346562721
        },
        {
            "few-shot hacking": 0.34419263456090654,
            "indirect task deflection": 0.9605911330049262,
            "instruction based hacking": 0.5107438016528926,
            "syntactical change": 0.4721311475409836,
            "insisting": 0.009900990099009901,
            "text-completion vs instruction tradeoff": 0.378698224852071,
            "cognitive hacking": 0.9951219512195122
        },
        [
            {
                "lang": 0.7301659125188538,
                "hate": 0.7687452313241313,
                "summary": 0.2915346597389431,
                "code": 0.28449730094466935
            },
            {
                "goal hijack": 0.5881081712516792,
                "prompt leakage": 0.440965131230618,
                "denial of service": 0.4360791582620074
            },
            {
                "few-shot hacking": 0.5838962736979734,
                "indirect task deflection": 0.25198938992042436,
                "instruction based hacking": 0.49421487603305786,
                "syntactical change": 0.5150063051702397,
                "insisting": 0.763899466869764,
                "text-completion vs instruction tradeoff": 0.5653163404642695,
                "cognitive hacking": 0.23339587242026266
            }
        ],
        {
            "goal hijack": 1317,
            "prompt leakage": 1017,
            "denial of service": 1411
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
                "denial of service": 0.26080793763288446
            },
            {
                "few-shot hacking": 0.28895184135977336,
                "indirect task deflection": 0.14532019704433496,
                "instruction based hacking": 0.2983471074380165,
                "syntactical change": 0.13442622950819672,
                "insisting": 0.14851485148514854,
                "text-completion vs instruction tradeoff": 0.0986193293885601,
                "cognitive hacking": 0.20975609756097557
            }
        ],
        {
            "goal hijack": 1317,
            "prompt leakage": 1017,
            "denial of service": 1411
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "FLAN": [
        {
            "total_success_fraction": 0.5070761014686248
        },
        {
            "lang": 0.4803921568627451,
            "hate": 0.0,
            "summary": 0.7380560131795717,
            "code": 0.831140350877193
        },
        {
            "goal hijack": 0.39863325740318906,
            "prompt leakage": 0.44346116027531957,
            "denial of service": 0.6541459957476967
        },
        {
            "few-shot hacking": 0.5708215297450425,
            "indirect task deflection": 0.7093596059113301,
            "instruction based hacking": 0.5099173553719009,
            "syntactical change": 0.4491803278688525,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.3136094674556213,
            "cognitive hacking": 0.7707317073170732
        },
        [
            {
                "lang": 0.5151683314835368,
                "hate": 0.8867924528301887,
                "summary": 0.31584346150259546,
                "code": 0.24383482290632238
            },
            {
                "goal hijack": 0.5784157820088538,
                "prompt leakage": 0.5437375929945641,
                "denial of service": 0.3807549844215931
            },
            {
                "few-shot hacking": 0.44521353359345767,
                "indirect task deflection": 0.33804256901199,
                "instruction based hacking": 0.49232808358022767,
                "syntactical change": 0.539313331271265,
                "insisting": 0.8867924528301886,
                "text-completion vs instruction tradeoff": 0.6441889025343308,
                "cognitive hacking": 0.29056603773584905
            }
        ],
        {
            "goal hijack": 1317,
            "prompt leakage": 1017,
            "denial of service": 1411
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
}

# %%
data = {
    "TURBO": [
        {
            "total_success_fraction": 0.4851720047449585
        },
        {
            "Translation": 0.624390243902439,
            "Text Classification": 0.4328147100424328,
            "Summarization": 0.49814585908529047,
            "Code Generation": 0.48267326732673266
        },
        {
            "goal hijack": 0.6032786885245902,
            "prompt leakage": 0.9978165938864629,
            "denial of service": 0.09862385321100918
        },
        {
            "syntactical change": 0.3344262295081967,
            "instruction based hacking": 0.5693832599118943,
            "text-completion vs instruction tradeoff": 0.49876543209876545,
            "cognitive hacking": 0.995049504950495,
            "indirect task deflection": 0.0049504950495049506,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "codex": [
        {
            "total_success_fraction": 0.39628865979381445
        },
        {
            "Translation": 0.4975609756097561,
            "Text Classification": 0.42715700141442714,
            "Summarization": 0.4314002828854314,
            "Code Generation": 0.31265508684863524
        },
        {
            "goal hijack": 0.23529411764705882,
            "prompt leakage": 0.9945235487404163,
            "denial of service": 0.00382262996941896
        },
        {
            "syntactical change": 0.33278688524590166,
            "instruction based hacking": 0.4966960352422907,
            "text-completion vs instruction tradeoff": 0.3344370860927152,
            "cognitive hacking": 0.4975124378109453,
            "indirect task deflection": 0.024752475247524754,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "t_davinci2": [
        {
            "total_success_fraction": 0.28329896907216495
        },
        {
            "Translation": 0.35609756097560974,
            "Text Classification": 0.03818953323903819,
            "Summarization": 0.42857142857142855,
            "Code Generation": 0.3523573200992556
        },
        {
            "goal hijack": 0.46568627450980393,
            "prompt leakage": 0.6484118291347207,
            "denial of service": 0.0
        },
        {
            "syntactical change": 0.16721311475409836,
            "instruction based hacking": 0.42180616740088106,
            "text-completion vs instruction tradeoff": 0.0,
            "cognitive hacking": 0.5024875621890548,
            "indirect task deflection": 0.0,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "curie": [
        {
            "total_success_fraction": 0.21195876288659793
        },
        {
            "Translation": 0.4682926829268293,
            "Text Classification": 0.0,
            "Summarization": 0.42857142857142855,
            "Code Generation": 0.14267990074441686
        },
        {
            "goal hijack": 0.00980392156862745,
            "prompt leakage": 0.56078860898138,
            "denial of service": 0.0
        },
        {
            "syntactical change": 0.16721311475409836,
            "instruction based hacking": 0.2654185022026432,
            "text-completion vs instruction tradeoff": 0.0,
            "cognitive hacking": 0.5024875621890548,
            "indirect task deflection": 0.0,
            "few-shot hacking": 0.3482587064676617
        }
    ],
    "babbage": [
        {
            "total_success_fraction": 0.2334020618556701
        },
        {
            "Translation": 0.375609756097561,
            "Text Classification": 0.0,
            "Summarization": 0.42857142857142855,
            "Code Generation": 0.23076923076923078
        },
        {
            "goal hijack": 0.0196078431372549,
            "prompt leakage": 0.6046002190580504,
            "denial of service": 0.00764525993883792
        },
        {
            "syntactical change": 0.16721311475409836,
            "instruction based hacking": 0.28744493392070486,
            "text-completion vs instruction tradeoff": 0.0,
            "cognitive hacking": 0.5024875621890548,
            "indirect task deflection": 0.0049504950495049506,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "ada": [
        {
            "total_success_fraction": 0.32618556701030926
        },
        {
            "Translation": 0.44390243902439025,
            "Text Classification": 0.32814710042432815,
            "Summarization": 0.42857142857142855,
            "Code Generation": 0.20471464019851116
        },
        {
            "goal hijack": 0.00980392156862745,
            "prompt leakage": 0.8488499452354874,
            "denial of service": 0.010703363914373088
        },
        {
            "syntactical change": 0.3360655737704918,
            "instruction based hacking": 0.3766519823788546,
            "text-completion vs instruction tradeoff": 0.20860927152317882,
            "cognitive hacking": 0.5472636815920398,
            "indirect task deflection": 0.024752475247524754,
            "few-shot hacking": 0.32338308457711445
        }
    ],
    "BLOOMHUB": [
        {
            "total_success_fraction": 0.4247422680412371
        },
        {
            "Translation": 0.526829268292683,
            "Text Classification": 0.5714285714285714,
            "Summarization": 0.42998585572843,
            "Code Generation": 0.2655086848635236
        },
        {
            "goal hijack": 0.05392156862745098,
            "prompt leakage": 0.9912376779846659,
            "denial of service": 0.0871559633027523
        },
        {
            "syntactical change": 0.3737704918032787,
            "instruction based hacking": 0.5110132158590308,
            "text-completion vs instruction tradeoff": 0.4370860927152318,
            "cognitive hacking": 0.4925373134328358,
            "indirect task deflection": 0.024752475247524754,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "FLAN": [
        {
            "total_success_fraction": 0.22597938144329896
        },
        {
            "Translation": 0.32195121951219513,
            "Text Classification": 0.0,
            "Summarization": 0.36916548797736914,
            "Code Generation": 0.27419354838709675
        },
        {
            "goal hijack": 0.14705882352941177,
            "prompt leakage": 0.5169769989047097,
            "denial of service": 0.035168195718654434
        },
        {
            "syntactical change": 0.12950819672131147,
            "instruction based hacking": 0.2830396475770925,
            "text-completion vs instruction tradeoff": 0.0,
            "cognitive hacking": 0.40298507462686567,
            "indirect task deflection": 0.1485148514851485,
            "few-shot hacking": 0.5024875621890548
        }
    ],
    "OPT": [
        {
            "total_success_fraction": 0.4288659793814433
        },
        {
            "Translation": 0.4975609756097561,
            "Text Classification": 0.5785007072135785,
            "Summarization": 0.42857142857142855,
            "Code Generation": 0.2803970223325062
        },
        {
            "goal hijack": 0.03431372549019608,
            "prompt leakage": 0.9956188389923329,
            "denial of service": 0.09480122324159021
        },
        {
            "syntactical change": 0.39672131147540984,
            "instruction based hacking": 0.4889867841409692,
            "text-completion vs instruction tradeoff": 0.47019867549668876,
            "cognitive hacking": 0.5124378109452736,
            "indirect task deflection": 0.009900990099009901,
            "few-shot hacking": 0.527363184079602
        }
    ]
}

# %%
print(data.items())
# Out:
# dict_items([('TURBO', [{'total_success_fraction': 0.4851720047449585}, {'Translation': 0.624390243902439, 'Text Classification': 0.4328147100424328, 'Summarization': 0.49814585908529047, 'Code Generation': 0.48267326732673266}, {'goal hijack': 0.6032786885245902, 'prompt leakage': 0.9978165938864629, 'denial of service': 0.09862385321100918}, {'syntactical change': 0.3344262295081967, 'instruction based hacking': 0.5693832599118943, 'text-completion vs instruction tradeoff': 0.49876543209876545, 'cognitive hacking': 0.995049504950495, 'indirect task deflection': 0.0049504950495049506, 'few-shot hacking': 0.5024875621890548}]), ('codex', [{'total_success_fraction': 0.39628865979381445}, {'Translation': 0.4975609756097561, 'Text Classification': 0.42715700141442714, 'Summarization': 0.4314002828854314, 'Code Generation': 0.31265508684863524}, {'goal hijack': 0.23529411764705882, 'prompt leakage': 0.9945235487404163, 'denial of service': 0.00382262996941896}, {'syntactical change': 0.33278688524590166, 'instruction based hacking': 0.4966960352422907, 'text-completion vs instruction tradeoff': 0.3344370860927152, 'cognitive hacking': 0.4975124378109453, 'indirect task deflection': 0.024752475247524754, 'few-shot hacking': 0.5024875621890548}]), ('t_davinci2', [{'total_success_fraction': 0.28329896907216495}, {'Translation': 0.35609756097560974, 'Text Classification': 0.03818953323903819, 'Summarization': 0.42857142857142855, 'Code Generation': 0.3523573200992556}, {'goal hijack': 0.46568627450980393, 'prompt leakage': 0.6484118291347207, 'denial of service': 0.0}, {'syntactical change': 0.16721311475409836, 'instruction based hacking': 0.42180616740088106, 'text-completion vs instruction tradeoff': 0.0, 'cognitive hacking': 0.5024875621890548, 'indirect task deflection': 0.0, 'few-shot hacking': 0.5024875621890548}]), ('curie', [{'total_success_fraction': 0.21195876288659793}, {'Translation': 0.4682926829268293, 'Text Classification': 0.0, 'Summarization': 0.42857142857142855, 'Code Generation': 0.14267990074441686}, {'goal hijack': 0.00980392156862745, 'prompt leakage': 0.56078860898138, 'denial of service': 0.0}, {'syntactical change': 0.16721311475409836, 'instruction based hacking': 0.2654185022026432, 'text-completion vs instruction tradeoff': 0.0, 'cognitive hacking': 0.5024875621890548, 'indirect task deflection': 0.0, 'few-shot hacking': 0.3482587064676617}]), ('babbage', [{'total_success_fraction': 0.2334020618556701}, {'Translation': 0.375609756097561, 'Text Classification': 0.0, 'Summarization': 0.42857142857142855, 'Code Generation': 0.23076923076923078}, {'goal hijack': 0.0196078431372549, 'prompt leakage': 0.6046002190580504, 'denial of service': 0.00764525993883792}, {'syntactical change': 0.16721311475409836, 'instruction based hacking': 0.28744493392070486, 'text-completion vs instruction tradeoff': 0.0, 'cognitive hacking': 0.5024875621890548, 'indirect task deflection': 0.0049504950495049506, 'few-shot hacking': 0.5024875621890548}]), ('ada', [{'total_success_fraction': 0.32618556701030926}, {'Translation': 0.44390243902439025, 'Text Classification': 0.32814710042432815, 'Summarization': 0.42857142857142855, 'Code Generation': 0.20471464019851116}, {'goal hijack': 0.00980392156862745, 'prompt leakage': 0.8488499452354874, 'denial of service': 0.010703363914373088}, {'syntactical change': 0.3360655737704918, 'instruction based hacking': 0.3766519823788546, 'text-completion vs instruction tradeoff': 0.20860927152317882, 'cognitive hacking': 0.5472636815920398, 'indirect task deflection': 0.024752475247524754, 'few-shot hacking': 0.32338308457711445}]), ('BLOOMHUB', [{'total_success_fraction': 0.4247422680412371}, {'Translation': 0.526829268292683, 'Text Classification': 0.5714285714285714, 'Summarization': 0.42998585572843, 'Code Generation': 0.2655086848635236}, {'goal hijack': 0.05392156862745098, 'prompt leakage': 0.9912376779846659, 'denial of service': 0.0871559633027523}, {'syntactical change': 0.37377049180 ...

# %%
import pandas as pd

# %%
plt.clf()

# %%
index = [type_mapping[k] for model,value in data.items() for k,v in value[3].items()]
index
# Out:
# ['SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH',
#  'SYN',
#  'INSTR',
#  'TCINS',
#  'COG',
#  'ITD',
#  'FSH']

# %%
df
# Out:
#            TURBO      codex  t_davinci2      curie    babbage        ada  \
# SYN    33.442623  33.278689   16.721311  16.721311  16.721311  33.606557
# INSTR  56.938326  49.669604   42.180617  26.541850  28.744493  37.665198
# TCINS  49.876543  33.443709    0.000000   0.000000   0.000000  20.860927
# COG    99.504950  49.751244   50.248756  50.248756  50.248756  54.726368
# ITD     0.495050   2.475248    0.000000   0.000000   0.495050   2.475248
# FSH    50.248756  50.248756   50.248756  34.825871  50.248756  32.338308
#
#         BLOOMHUB       FLAN        OPT
# SYN    37.377049  12.950820  39.672131
# INSTR  51.101322  28.303965  48.898678
# TCINS  43.708609   0.000000  47.019868
# COG    49.253731  40.298507  51.243781
# ITD     2.475248  14.851485   0.990099
# FSH    50.248756  50.248756  52.736318

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 
attack_types = data['OPT'][3].keys()
type_mapping = {
            "syntactical change": 'SYN',
            "instruction based hacking": 'INSTR',
            "text-completion vs instruction tradeoff": 'TCINS',
            "cognitive hacking": 'COG',
            "indirect task deflection": 'ITD',
            "few-shot hacking": 'FSH'
}

df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[3].items()] for model,value in data.items()
    }, index = [type_mapping[k] for k,v in data['OPT'][3].items()] )

my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(12, 5))

fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Jailbreak Type', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i])
    # set the bar labels below each bar for each model

    # for p in c.patches:
    #     ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x(), p.get_height()+2), fontsize=7.7, rotation=0, font='monospace', color='black')


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)

x_coords = [0.5,1.5,2.5,3.5,4.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,5.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(1.2, 0), loc='lower right', ncol=1)
plt.show()
plt.savefig('type.png')

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 
x = ['Translation','Text\nClassification','Summarization','Code\nGeneration']
df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[1].items()] for model,value in data.items()
    }, index= [k for k,v in data['OPT'][1].items()])

my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(6, 5))
fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i])
    # set the bar labels below each bar for each model

# for p in c.patches:
#     ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x(), p.get_height()+2), fontsize=7.7, rotation=0, font='monospace', color='black')


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)


ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5,2.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,3.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.show()
plt.savefig('task.png')

# %%
pd.set_option("display.precision", 2)
df
# Out:
#                      TURBO  codex  t_davinci2  curie  babbage    ada  \
# Translation          62.44  49.76       35.61  46.83    37.56  44.39
# Text Classification  43.28  42.72        3.82   0.00     0.00  32.81
# Summarization        49.81  43.14       42.86  42.86    42.86  42.86
# Code Generation      48.27  31.27       35.24  14.27    23.08  20.47
#
#                      BLOOMHUB   FLAN    OPT
# Translation             52.68  32.20  49.76
# Text Classification     57.14   0.00  57.85
# Summarization           43.00  36.92  42.86
# Code Generation         26.55  27.42  28.04

# %%
df
# Out:
#                        TURBO      codex  t_davinci2      curie    babbage  \
# Goal Hijack        60.327869  23.529412   46.568627   0.980392   1.960784
# Prompt Leakage     99.781659  99.452355   64.841183  56.078861  60.460022
# Denial of Service   9.862385   0.382263    0.000000   0.000000   0.764526
#
#                          ada   BLOOMHUB       FLAN        OPT
# Goal Hijack         0.980392   5.392157  14.705882   3.431373
# Prompt Leakage     84.884995  99.123768  51.697700  99.561884
# Denial of Service   1.070336   8.715596   3.516820   9.480122

# %%
list(data.items())[0]
# Out:
# ('OPT',
#  [{'total_success_fraction': 0.4296907216494845},
#   {'Translation': 0.4975609756097561,
#    'Text Classification': 0.57991513437058,
#    'Summarization': 0.42857142857142855,
#    'Code Generation': 0.2816377171215881},
#   {'Goal Hijack': 0.03431372549019608,
#    'prompt leakage': 0.9978094194961665,
#    'Denial of Service': 0.01791044776119403,
#    'Denial Of Service': 0.34983498349834985},
#   {'syntactical change': 0.3983606557377049,
#    'instruction based hacking': 0.4889867841409692,
#    'insisting': 1.0,
#    'text-completion vs instruction tradeoff': 0.47019867549668876,
#    'cognitive hacking': 0.5124378109452736,
#    'indirect task deflection': 0.009900990099009901,
#    'few-shot hacking': 0.5323383084577115}])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 

x = ['Goal Hijack','Prompt Leakage','Denial of Service']
df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[2].items()] for model,value in data.items()
    }, index= [k for k,v in data['OPT'][2].items()])
df.index = x
my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(6, 5))
fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Jailbreak Intent', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i])
    # set the bar labels below each bar for each model

# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)

# remove grid

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,2.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.show()
