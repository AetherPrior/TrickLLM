# %% [markdown]
# # Data
# The data had to be reordered for ease in plotting
# The statistics are present in the file `prop-test-outputs.json`
# The schema is as follows:

# %%
data = {
    "gpt-3.5-turbo": [
        {
            "total_success_fraction": 0.5495327102803739
        },
        {
            "lang": 0.25882352941176473,
            "hate": 0.013525698827772768,
            "summary": 0.9044481054365733,
            "code": 0.8914473684210527
        },
        {
            "goal hijack": 0.3344316309719934,
            "denial of service": 0.6433289299867899,
            "prompt leakage": 0.6666666666666666
        },
        {
            "few-shot hacking": 0.2988668555240793,
            "indirect task deflection": 0.9876847290640394,
            "instruction based hacking": 0.6074380165289256,
            "syntactical change": 0.5016393442622951,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.39644970414201186,
            "cognitive hacking": 0.9951219512195122
        },
        [
            {
                "lang": 0.5717011128775834,
                "hate": 0.6446274949430947,
                "summary": 0.37975867135669444,
                "code": 0.3836237553342816
            },
            {
                "goal hijack": 0.5492230286299479,
                "denial of service": 0.45738869649041386,
                "prompt leakage": 0.4504504504504504
            },
            {
                "few-shot hacking": 0.5597963402495981,
                "indirect task deflection": 0.3550126481160964,
                "instruction based hacking": 0.4680589680589681,
                "syntactical change": 0.49951262738147983,
                "insisting": 0.6486486486486487,
                "text-completion vs instruction tradeoff": 0.5307852230929154,
                "cognitive hacking": 0.3528015820698747
            }
        ],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "codex": [
        {
            "total_success_fraction": 0.5169559412550067
        },
        {
            "lang": 0.07254901960784314,
            "hate": 0.0009017132551848512,
            "summary": 0.8871499176276771,
            "code": 0.9002192982456141
        },
        {
            "goal hijack": 0.36326194398682043,
            "denial of service": 0.5779392338177014,
            "prompt leakage": 0.6096361848574238
        },
        {
            "few-shot hacking": 0.34419263456090654,
            "indirect task deflection": 0.9605911330049262,
            "instruction based hacking": 0.5107438016528926,
            "syntactical change": 0.4721311475409836,
            "insisting": 0.009900990099009901,
            "text-completion vs instruction tradeoff": 0.378698224852071,
            "cognitive hacking": 0.9951219512195122
        },
        [
            {
                "lang": 0.7301659125188538,
                "hate": 0.7687452313241313,
                "summary": 0.2915346597389431,
                "code": 0.28449730094466935
            },
            {
                "goal hijack": 0.5736281840070968,
                "denial of service": 0.458032720252007,
                "prompt leakage": 0.440965131230618
            },
            {
                "few-shot hacking": 0.5838962736979734,
                "indirect task deflection": 0.25198938992042436,
                "instruction based hacking": 0.49421487603305786,
                "syntactical change": 0.5150063051702397,
                "insisting": 0.763899466869764,
                "text-completion vs instruction tradeoff": 0.5653163404642695,
                "cognitive hacking": 0.23339587242026266
            }
        ],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "t_davinci2": [
        {
            "total_success_fraction": 0.34873164218958613
        },
        {
            "lang": 0.00392156862745098,
            "hate": 0.04508566275924256,
            "summary": 0.8640856672158155,
            "code": 0.22478070175438597
        },
        {
            "goal hijack": 0.2158154859967051,
            "denial of service": 0.33619550858652575,
            "prompt leakage": 0.5260570304818093
        },
        {
            "few-shot hacking": 0.11614730878186968,
            "indirect task deflection": 0.8817733990147784,
            "instruction based hacking": 0.3239669421487603,
            "syntactical change": 0.36065573770491804,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.28994082840236685,
            "cognitive hacking": 0.5219512195121951
        },
        [],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "curie": [
        {
            "total_success_fraction": 0.48651535380507344
        },
        {
            "lang": 0.0058823529411764705,
            "hate": 0.002705139765554554,
            "summary": 0.8484349258649094,
            "code": 0.8618421052631579
        },
        {
            "goal hijack": 0.34761120263591433,
            "denial of service": 0.5528401585204755,
            "prompt leakage": 0.5535889872173058
        },
        {
            "few-shot hacking": 0.37110481586402266,
            "indirect task deflection": 0.9482758620689655,
            "instruction based hacking": 0.4644628099173554,
            "syntactical change": 0.47704918032786886,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.252465483234714,
            "cognitive hacking": 0.9463414634146341
        },
        [],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "babbage": [
        {
            "total_success_fraction": 0.42269692923898533
        },
        {
            "lang": 0.09215686274509804,
            "hate": 0.0,
            "summary": 0.8278418451400329,
            "code": 0.5822368421052632
        },
        {
            "goal hijack": 0.3237232289950577,
            "denial of service": 0.4418758256274769,
            "prompt leakage": 0.512291052114061
        },
        {
            "few-shot hacking": 0.29036827195467424,
            "indirect task deflection": 0.8103448275862069,
            "instruction based hacking": 0.40743801652892564,
            "syntactical change": 0.4360655737704918,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.28205128205128205,
            "cognitive hacking": 0.7170731707317073
        },
        [],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "ada": [
        {
            "total_success_fraction": 0.4643524699599466
        },
        {
            "lang": 0.16666666666666666,
            "hate": 0.0,
            "summary": 0.8962108731466227,
            "code": 0.6206140350877193
        },
        {
            "goal hijack": 0.3542009884678748,
            "denial of service": 0.48811096433289297,
            "prompt leakage": 0.56047197640118
        },
        {
            "few-shot hacking": 0.301699716713881,
            "indirect task deflection": 0.896551724137931,
            "instruction based hacking": 0.47851239669421486,
            "syntactical change": 0.4540983606557377,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.3727810650887574,
            "cognitive hacking": 0.5707317073170731
        },
        [],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "BLOOMHUB": [
        {
            "total_success_fraction": 0.7033377837116155
        },
        {
            "lang": 0.48823529411764705,
            "hate": 0.7105500450856628,
            "summary": 0.886326194398682,
            "code": 0.5712719298245614
        },
        {
            "goal hijack": 0.5831960461285008,
            "denial of service": 0.691545574636724,
            "prompt leakage": 0.8643067846607669
        },
        {
            "few-shot hacking": 0.5410764872521246,
            "indirect task deflection": 0.8251231527093597,
            "instruction based hacking": 0.6834710743801653,
            "syntactical change": 0.8,
            "insisting": 0.5247524752475248,
            "text-completion vs instruction tradeoff": 0.7850098619329389,
            "cognitive hacking": 0.7365853658536585
        },
        [],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "OPT": [
        {
            "total_success_fraction": 0.7826435246995994
        },
        {
            "lang": 0.5235294117647059,
            "hate": 0.8539224526600541,
            "summary": 0.9102141680395387,
            "code": 0.6710526315789473
        },
        {
            "goal hijack": 0.7347611202635914,
            "denial of service": 0.749669749009247,
            "prompt leakage": 0.8888888888888888
        },
        {
            "few-shot hacking": 0.7110481586402266,
            "indirect task deflection": 0.854679802955665,
            "instruction based hacking": 0.7016528925619835,
            "syntactical change": 0.8655737704918033,
            "insisting": 0.8514851485148515,
            "text-completion vs instruction tradeoff": 0.9013806706114399,
            "cognitive hacking": 0.7902439024390244
        },
        [
            {
                "lang": 0.4764705882352941,
                "hate": 0.14607754733994593,
                "summary": 0.0897858319604613,
                "code": 0.32894736842105265
            },
            {
                "goal hijack": 0.2652388797364086,
                "denial of service": 0.250330250990753,
                "prompt leakage": 0.11111111111111116
            },
            {
                "few-shot hacking": 0.28895184135977336,
                "indirect task deflection": 0.14532019704433496,
                "instruction based hacking": 0.2983471074380165,
                "syntactical change": 0.13442622950819672,
                "insisting": 0.14851485148514854,
                "text-completion vs instruction tradeoff": 0.0986193293885601,
                "cognitive hacking": 0.20975609756097557
            }
        ],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    "FLAN": [
        {
            "total_success_fraction": 0.5070761014686248
        },
        {
            "lang": 0.4803921568627451,
            "hate": 0.0,
            "summary": 0.7380560131795717,
            "code": 0.831140350877193
        },
        {
            "goal hijack": 0.4316309719934102,
            "denial of service": 0.6103038309114928,
            "prompt leakage": 0.44346116027531957
        },
        {
            "few-shot hacking": 0.5708215297450425,
            "indirect task deflection": 0.7093596059113301,
            "instruction based hacking": 0.5099173553719009,
            "syntactical change": 0.4491803278688525,
            "insisting": 0.0,
            "text-completion vs instruction tradeoff": 0.3136094674556213,
            "cognitive hacking": 0.7707317073170732
        },
        [
            {
                "lang": 0.5151683314835368,
                "hate": 0.8867924528301887,
                "summary": 0.31584346150259546,
                "code": 0.24383482290632238
            },
            {
                "goal hijack": 0.5528892480805695,
                "denial of service": 0.4146706213703547,
                "prompt leakage": 0.5437375929945641
            },
            {
                "few-shot hacking": 0.44521353359345767,
                "indirect task deflection": 0.33804256901199,
                "instruction based hacking": 0.49232808358022767,
                "syntactical change": 0.539313331271265,
                "insisting": 0.8867924528301886,
                "text-completion vs instruction tradeoff": 0.6441889025343308,
                "cognitive hacking": 0.29056603773584905
            }
        ],
        {
            "goal hijack": 1214,
            "denial of service": 1514,
            "prompt leakage": 1017
        },
        {
            "lang": 510,
            "hate": 1109,
            "summary": 1214,
            "code": 912
        },
        {
            "few-shot hacking": 706,
            "indirect task deflection": 406,
            "instruction based hacking": 1210,
            "syntactical change": 610,
            "insisting": 101,
            "text-completion vs instruction tradeoff": 507,
            "cognitive hacking": 205
        }
    ],
    
}

# %%
print(data.items())
# Out:
# dict_items([('gpt-3.5-turbo', [{'total_success_fraction': 0.5495327102803739}, {'lang': 0.25882352941176473, 'hate': 0.013525698827772768, 'summary': 0.9044481054365733, 'code': 0.8914473684210527}, {'goal hijack': 0.3344316309719934, 'denial of service': 0.6433289299867899, 'prompt leakage': 0.6666666666666666}, {'few-shot hacking': 0.2988668555240793, 'indirect task deflection': 0.9876847290640394, 'instruction based hacking': 0.6074380165289256, 'syntactical change': 0.5016393442622951, 'insisting': 0.0, 'text-completion vs instruction tradeoff': 0.39644970414201186, 'cognitive hacking': 0.9951219512195122}, [{'lang': 0.5717011128775834, 'hate': 0.6446274949430947, 'summary': 0.37975867135669444, 'code': 0.3836237553342816}, {'goal hijack': 0.5492230286299479, 'denial of service': 0.45738869649041386, 'prompt leakage': 0.4504504504504504}, {'few-shot hacking': 0.5597963402495981, 'indirect task deflection': 0.3550126481160964, 'instruction based hacking': 0.4680589680589681, 'synt
# ...

# %%
import pandas as pd

# %%
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/asura/Documents/git-clones/PAWG/src/eval/attackmetrics/plot_proptest_results.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/home/asura/Documents/git-clones/PAWG/src/eval/attackmetrics/plot_proptest_results.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> plt.clf()
#
# NameError: name 'plt' is not defined

# %%
df
# Out:
#        gpt-3.5-turbo  code-davinci-002  text-davinci-002      curie  \
# FSH        29.886686         34.419263         11.614731  37.110482
# ITD        98.768473         96.059113         88.177340  94.827586
# INSTR      60.743802         51.074380         32.396694  46.446281
# ORTH       50.163934         47.213115         36.065574  47.704918
# IR          0.000000          0.990099          0.000000   0.000000
# TCINS      39.644970         37.869822         28.994083  25.246548
# COG        99.512195         98.048780         77.073171  90.731707
#
#          babbage        ada        OPT      BLOOM       FLAN
# FSH    29.036827  30.169972  71.104816  54.107649  57.082153
# ITD    81.034483  89.655172  85.467980  82.512315  70.935961
# INSTR  40.743802  47.851240  70.165289  68.347107  50.991736
# ORTH   43.606557  45.409836  86.557377  80.000000  44.918033
# IR      0.000000   0.000000  85.148515  52.475248   0.000000
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import copy
mpl.rc("figure",dpi=200)
# %matplotlib inline 
x = ['FSH', 'ITD', 'INSTR', 'ORTH','IR','TCINS','COG' ]
df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[3].items()] for model,value in data.items()
    }, index=x)

df_scaled = pd.DataFrame(data = {
        model+'_scaled' : [v*100 for k,v in value[4][2].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)

df.index = x
my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(13, 5))

fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Jailbreak Type', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i],alpha=0.6)
    hatch_to_model = {'gpt-3.5-turbo':'/o/o', 'codex':'...', 'OPT':'xxx', 'FLAN':'\\\\\\'}
    if col in ['gpt-3.5-turbo','codex','OPT','FLAN']:
        # print("here")
        
        # ax.bar(x=[position+p for p in range(len(df_scaled))], height=df_scaled[col], width=0.09, color=my_colors[i], alpha=0.4)
        
        sc = df_scaled[col+'_scaled'].plot(kind='bar', rot=0, xlabel='Jailbreak Type', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i], 
                                           alpha=0.6,
                                           zorder=0)
        bars = sc.patches
        # subtract the patches from bars
        bars = sc.patches[-len(df_scaled):]
        
        # print(len(bars))
        # print('----')
        for bar in bars:
            bar.set_hatch(hatch_to_model[col])
            bar.set_edgecolor(color=(0,0,0,1))
    # set the bar labels below each bar for each model

    # for p in c.patches:
    #     ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x(), p.get_height()+2), fontsize=7.7, rotation=0, font='monospace', color='black')


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, (p.get_height()+2)*1.01), fontsize=9, rotation=90, color=(0,0,0,1), font='monospace', zorder=10)

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)

x_coords = [0.5,1.5,2.5,3.5,4.5,5.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,6.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(1.2, 0), loc='lower right', ncol=1)

import os
print(os.getcwd())
plt.savefig('../../../plots/jailbreak_success_by_type.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()
# Out:
# /home/asura/Documents/git-clones/PAWG/src/eval/attackmetrics

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 

x = ['Translation','Text\nClassification','Summarization','Code\nGeneration']
df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[1].items()] for model,value in data.items()
    }, index=x)
df_scaled = pd.DataFrame(data = {
        model+'_scaled' : [v*100 for k,v in value[4][0].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)
df.index = x
my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(6, 7))
fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i],alpha=0.6)
    # set the bar labels below each bar for each model
    hatch_to_model = {'gpt-3.5-turbo':'///', 'codex':'...', 'OPT':'xxx', 'FLAN':'\\\\\\'}
    if col in ['gpt-3.5-turbo','codex','OPT','FLAN']:
        # print("here")
        
        # ax.bar(x=[position+p for p in range(len(df_scaled))], height=df_scaled[col], width=0.09, color=my_colors[i], alpha=0.4)
        
        sc = df_scaled[col+'_scaled'].plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i], alpha=0.6)
        bars = sc.patches
        # subtract the patches from bars
        bars = sc.patches[-len(df_scaled):]
        
        # print(len(bars))
        # print('----')
        for bar in bars:
            bar.set_hatch(hatch_to_model[col])
            bar.set_edgecolor(color=(0,0,0,0.2))
# for p in c.patches:
#     ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x(), p.get_height()+2), fontsize=7.7, rotation=0, font='monospace', color='black')


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)


ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5,2.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,3.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.savefig('../../../plots/jailbreak_success_by_task.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 

x = ['Misaligned Content\n Generation','Information Leakage','Performance\n Degradation']
df = pd.DataFrame(data = {
        model : [v*100 for k,v in value[2].items()] for model,value in data.items()
    }, index=x)
df_scaled = pd.DataFrame(data = {
        model+'_scaled' : [v*100 for k,v in value[4][1].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)
df.index = x
my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(6, 7))
fig.subplots_adjust(bottom=0.2)
hatch_to_model = {'gpt-3.5-turbo':'/o/o', 'codex':'...', 'OPT':'xxx', 'FLAN':'\\\\\\'}
for i, col in enumerate(df.columns[::-1]):
    # dont make the bars overlap
    position = i-4 if i < 3 else i+0.8-4
    c = df[col].plot(kind='bar', rot=0, xlabel='Jailbreak Intent', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i], alpha=0.6)
    if col in ['gpt-3.5-turbo','codex','OPT','FLAN']:
        # print("here")
        
        # ax.bar(x=[position+p for p in range(len(df_scaled))], height=df_scaled[col], width=0.09, color=my_colors[i], alpha=0.4)
        
        sc = df_scaled[col+'_scaled'].plot(kind='bar', rot=0, xlabel='Jailbreak Intent', ylabel='Success Rate of Jailbreaks (%)', width=0.09, position=position, ax=ax, color=my_colors[i], alpha=0.6)
        bars = sc.patches
        # subtract the patches from bars
        bars = sc.patches[-len(df_scaled):]
        
        # print(len(bars))
        # print('----')
        for bar in bars:
            bar.set_hatch(hatch_to_model[col])
            bar.set_edgecolor(color=(0,0,0,0.2))
    # set the bar labels below each bar for each model

# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)

# remove grid

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,2.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.savefig('../../../plots/jailbreak_success_by_intent.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import copy
mpl.rc("figure",dpi=200)
# %matplotlib inline 
x = ['FSH', 'ITD', 'INSTR', 'ORTH','IR','TCINS','COG' ]

df_scaled = pd.DataFrame(data = {
        model : [v*100 for k,v in value[4][2].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)

my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(10, 5))

fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df_scaled.columns[::-1]):
    # dont make the bars overlap
    position = 1.5*i-1
    c = df_scaled[col].plot(kind='bar', rot=0, xlabel='Jailbreak Type', ylabel='Success Rate of Jailbreaks (%)', width=0.12, position=position, ax=ax, color=my_colors[i],alpha=1)
    # set the bar labels below each bar for each model

    # for p in c.patches:
    #     ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x(), p.get_height()+2), fontsize=7.7, rotation=0, font='monospace', color='black')


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, (p.get_height()+2)*1.01), fontsize=8, rotation=90, color=(0,0,0,1))

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)

x_coords = [0.5,1.5,2.5,3.5,4.5,5.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,6.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(1.2, 0), loc='lower right', ncol=1)

import os
print(os.getcwd())
plt.savefig('../../../plots/jailbreak_success_scaled_by_type.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()
# Out:
# /home/asura/Documents/git-clones/PAWG/src/eval/attackmetrics

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 

x = ['Translation','Text\nClassification','Summarization','Code\nGeneration']

df_scaled = pd.DataFrame(data = {
        model : [v*100 for k,v in value[4][0].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)

my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(6, 5))
fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df_scaled.columns[::-1]):
    # dont make the bars overlap
    position = 1.5*i-1.5    
    c = df_scaled[col].plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Jailbreaks (%)', width=0.15, position=position, ax=ax, color=my_colors[i],alpha=1)


# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)


ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5,2.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,3.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)
ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.savefig('../../../plots/jailbreak_success_scaled_by_task.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()

# %%
# plot scaled results separately

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc("figure",dpi=200)
# %matplotlib inline 

x = ['Misaligned Content','Prompt Leakage','Performance Degradation']
df_scaled = pd.DataFrame(data = {
        model: [v*100 for k,v in value[4][1].items()] for model,value in data.items() if model in ['gpt-3.5-turbo','codex','OPT','FLAN']
    }, index=x)
my_colors = ['r','g','c']+[(x/5.0, x/8.0, 0.75) for x in range(6)[::-1]] # <-- Quick gradient example along the Red/Green dimensions.

#ax = df.plot(kind='bar', rot=0, xlabel='Task', ylabel='Success Rate of Attacks (%)', figsize=(10, 6),width=0.8,color=my_colors, subplots=True)

# plot each row in a column as a group of bars, where the 6th bar is separated from the 7th without df.plot
fig, ax = plt.subplots(figsize=(5, 5))
fig.subplots_adjust(bottom=0.2)
for i, col in enumerate(df_scaled.columns[::-1]):
    # dont make the bars overlap
    position = 2*i-2.5
    c = df_scaled[col].plot(kind='bar', rot=0, xlabel='Jailbreak Intent', ylabel='Success Rate of Jailbreaks (%)', width=0.13, position=position, ax=ax, color=my_colors[i])

# set the bar labels below each bar for each model
for p in ax.patches:
    ax.annotate(str(int(round(p.get_height(), 0))), (p.get_x()+0.01, p.get_height()+2), fontsize=8, rotation=90)

# remove grid

ax.grid(True, axis='y', linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)


x_coords = [0.5,1.5]
for x_c in x_coords:
    plt.axvline(x=x_c, color='k', linestyle='--', linewidth=1)
#ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

# display the value on the bottom of the bar (not the center), vertical aligned
    # ax.bar_label(c, fmt='%.0f', label_type='edge', fontsize=8, rotation=90)
    # add some offset to the value label
ax.set_xlim((-0.5,2.5))
ax.margins(y=0.1)
#ax.set_xlim(xmin=-0.3, xmax=6.3)

ax.legend(title='Models', bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.savefig('../../../plots/jailbreak_success_scaled_by_intent.png', format='png', dpi=1200, bbox_inches='tight')
plt.show()
